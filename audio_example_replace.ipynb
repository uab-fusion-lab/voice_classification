# %%
import torchaudio
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F

import os
import pandas as pd
import torchaudio
from torch.utils.data import Dataset, DataLoader, random_split
import torch
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
labels_df = pd.read_excel('./data/data/NEW_IRB300012145_Patient_ID_deidentified.xlsx')
smoking_status = labels_df.iloc[:, [0,21]]
smoking_status.iloc[:, 0] = smoking_status.iloc[:, 0].apply(lambda x: x[-3:])

filtered_df = smoking_status[smoking_status.iloc[:, 1] != 'Data not available']

label_list = list(filtered_df.itertuples(index=False, name=None))
label_list
# Out:
# [('020', 'Normal'),
#  ('022', 'Normal'),
#  ('023', 'Normal'),
#  ('024', 'Normal'),
#  ('025', 'Obstructive vent. Defect'),
#  ('026', 'Normal'),
#  ('029', 'Normal'),
#  ('030', 'Restrictive vent. Defect'),
#  ('031', 'Normal'),
#  ('032', 'Normal'),
#  ('033', 'Normal'),
#  ('034', 'Obstr. Cannot R/O Restriction'),
#  ('035', 'Restrictive vent. Defect'),
#  ('036', 'Normal'),
#  ('037', 'Restrictive vent. Defect'),
#  ('038', 'Normal'),
#  ('039', 'Normal'),
#  ('040', 'Normal'),
#  ('041', 'Obstructive vent. Defect'),
#  ('042', 'Normal'),
#  ('043', 'Normal'),
#  ('044', 'Normal'),
#  ('045', 'Obstructive vent. Defect'),
#  ('046', 'Normal'),
#  ('047', 'Obstructive vent. Defect'),
#  ('048', 'Obstr. Cannot R/O Restriction'),
#  ('049', 'Obstr. Cannot R/O Restriction'),
#  ('051', 'Obstr. Cannot R/O Restriction'),
#  ('052', 'Normal'),
#  ('053', 'Restrictive vent. Defect'),
#  ('054', 'Normal'),
#  ('057', 'Obstr. Cannot R/O Restriction'),
#  ('058', 'Obstructive vent. Defect'),
#  ('061', 'Restrictive vent. Defect'),
#  ('063', 'Obstr. Cannot R/O Restriction'),
#  ('064', 'Obstructive vent. Defect'),
#  ('065', 'Restrictive vent. Defect'),
#  ('066', 'Obstructive vent. Defect'),
#  ('067', 'Obstructive vent. Defect'),
#  ('068', 'Restrictive vent. Defect'),
#  ('069', 'Obstr. Cannot R/O Restriction'),
#  ('070', 'Obstructive vent. Defect'),
#  ('073', 'Obstr. Cannot R/O Restriction'),
#  ('074', 'Normal'),
#  ('075', 'Normal'),
#  ('076', 'Normal'),
#  ('078', 'Obstr. Cannot R/O Restriction'),
#  ('079', 'Normal'),
#  ('080', 'Restrictive vent. Defect'),
#  ('081', 'Normal'),
#  ('082', 'Normal'),
#  ('083', 'Restrictive vent. Defect'),
#  ('084', 'Normal'),
#  ('085', 'Restrictive vent. Defect'),
#  ('088', 'Normal'),
#  ('091', 'Obstructive vent. Defect'),
#  ('093', 'Restrictive vent. Defect'),
#  ('094', 'Restrictive vent. Defect'),
#  ('095', 'Obstr. Cannot R/O Restriction'),
#  ('098', 'Obstr. Cannot R/O Restriction'),
#  ('099', 'Restrictive vent. Defect'),
#  ('102', 'Normal'),
#  ('104', 'Normal'),
#  ('105', 'Obstr. Cannot R/O Restriction'),
#  ('107', 'Restrictive vent. Defect'),
#  ('108', 'Normal'),
#  ('109', 'Normal'),
#  ('110', 'Restrictive vent. Defect'),
#  ('111', 'Restrictive vent. Defect'),
#  ('112', 'Normal'),
#  ('113', 'Restrictive vent. Defect'),
#  ('114', 'Restrictive vent. Defect'),
#  ('115', 'Obstructive vent. Defect'),
#  ('116', 'Restrictive vent. Defect'),
#  ('117', 'Normal'),
#  ('118', 'Normal'),
#  ('119', 'Restrictive vent. Defect'),
#  ('120', 'Obstructive vent. Defect'),
#  ('121', 'Normal'),
#  ('122', 'Restrictive vent. Defect'),
#  ('123', 'Restrictive vent. Defect'),
#  ('124', 'Normal'),
#  ('125', 'Obstructive vent. Defect'),
#  ('126', 'Normal'),
#  ('127', 'Normal'),
#  ('128', 'Restrictive vent. Defect'),
#  ('129', 'Normal'),
#  ('130', 'Restrictive vent. Defect'),
#  ('131', 'Normal'),
#  ('132', 'Restrictive vent. Defect'),
#  ('133', 'Normal'),
#  ('134', 'Normal'),
#  ('135', 'Normal'),
#  ('136', 'Normal'),
#  ('137', 'Normal'),
#  ('138', 'Restrictive vent. Defect'),
#  ('139', 'Normal'),
#  ('140', 'Normal'),
#  ('141', 'Normal'),
#  ('142', 'Normal'),
#  ('143', 'Normal'),
#  ('145', 'Restrictive vent. Defect'),
#  ('147', 'Normal'),
#  ('149', 'Normal'),
#  ('150', 'Restrictive vent. Defect'),
#  ('151', 'Obstructive vent. Defect'),
#  ('152', 'Restrictive vent. Defect'),
#  ('153', 'Obstructive vent. Defect'),
#  ('154', 'Obstr. Cannot R/O Restriction'),
#  ('155', 'Restrictive vent. Defect'),
#  ('156', 'Restrictive vent. Defect'),
#  ('157', 'Obstr. Cannot R/O Restriction'),
#  ('158', 'Normal'),
#  ('159', 'Obstr. Cannot R/O Restriction'),
#  ('161', 'Normal'),
#  ('162', 'Restrictive vent. Defect'),
#  ('163', 'Restrictive vent. Defect'),
#  ('164', 'Restrictive vent. Defect'),
#  ('165', 'Restrictive vent. Defect'),
#  ('166', 'Restrictive vent. Defect'),
#  ('167', 'Restrictive vent. Defect'),
#  ('168', 'Obstr. Cannot R/O Restriction'),
#  ('170', 'Normal'),
#  ('171', 'Normal'),
#  ('172', 'Restrictive vent. Defect'),
#  ('173', 'Normal'),
#  ('174', 'Normal'),
#  ('175', 'Obstr. Cannot R/O Restriction'),
#  ('176', 'Normal'),
#  ('177', 'Obstr. Cannot R/O Restriction'),
#  ('178', 'Obstr. Cannot R/O Restriction'),
#  ('179', 'Obstructive vent. Defect'),
#  ('180', 'Obstructive vent. Defect'),
#  ('181', 'Normal'),
#  ('182', 'Restrictive vent. Defect'),
#  ('183', 'Restrictive vent. Defect'),
#  ('184', 'Restrictive vent. Defect'),
#  ('185', 'Restrictive vent. Defect'),
#  ('186', 'Normal'),
#  ('187', 'Restrictive vent. Defect'),
#  ('188', 'Restrictive vent. Defect'),
#  ('189', 'Normal'),
#  ('190', 'Normal'),
#  ('192', 'Obstructive vent. Defect'),
#  ('193', 'Obstructive vent. Defect'),
#  ('194', 'Obstructive vent. Defect'),
#  ('195', 'Restrictive vent. Defect'),
#  ('196', 'Restrictive vent. Defect'),
#  ('197', 'Restrictive vent. Defect'),
#  ('198', 'Obstr. Cannot R/O Restriction'),
#  ('199', 'Normal'),
#  ('200', 'Restrictive vent. Defect')]

# %%
import torchaudio.transforms as T

class AmplitudeNormalization:
    def __call__(self, waveform):
        # Normalize the waveform to be within [-1, 1]
        peak = waveform.abs().max()
        if peak > 0:
            waveform = waveform / peak
        return waveform

# To use it:
# waveform, sample_rate = torchaudio.load('path/to/audio.wav')
# waveform = AmplitudeNormalization()(waveform)


class PadTrimAudio:
    def __init__(self, max_len):
        self.max_len = max_len

    def __call__(self, waveform):
        if waveform.size(1) > self.max_len:
            # Trim the waveform if longer than max_len
            waveform = waveform[:, :self.max_len]
        elif waveform.size(1) < self.max_len:
            # Pad with zeros if shorter than max_len
            padding_size = self.max_len - waveform.size(1)
            waveform = torch.nn.functional.pad(waveform, (0, padding_size), "constant", 0)

        if waveform.size(0) < 128:
            padding_size = 128 - waveform.size(0)
            waveform = torch.nn.functional.pad(waveform, (padding_size, 0), "constant", 0)
        return waveform

from sklearn.preprocessing import StandardScaler
import numpy as np

class FeatureNormalization:
    def __init__(self):
        self.scaler = StandardScaler()

    def fit(self, features):
        # Fit the scaler on the training set features
        self.scaler.fit(features)

    def transform(self, features):
        # Apply normalization to features
        return self.scaler.transform(features)

# %%
label_to_int = {
    'Normal': 0,
    'Restrictive vent. Defect': 1,
    'Obstructive vent. Defect': 1,
    'Obstr. Cannot R/O Restriction': 1
}

# %%
class SoundDataset(Dataset):
    def __init__(self, data_dir, labels_df, transform=None, max_len=1000):
        self.data_dir = data_dir
        self.labels_df = labels_df
        self.transform = transform
        self.max_len = max_len
        self.orderlist = ['RLP.wav', 'RUP.wav', 'RUA Hum.wav', 'LUA Hum.wav', 'RUA.wav', 'RMP.wav', 'LMP.wav', 'LUA.wav', 'LLP.wav', 'LUP.wav']



    def __len__(self):
        return len(self.labels_df)

    def __getitem__(self, idx):
        patient_id = self.labels_df[idx][0]
        audio_dir = os.path.join(self.data_dir, str(patient_id), 'breath Eko')
        # audio_dir = os.path.join(self.data_dir, str(patient_id), 'Voice')
        audio_files = [os.path.join(audio_dir, f) for f in os.listdir(audio_dir) if f.endswith('.wav')]

        # Concatenate audio files
        waveform_list = [torch.zeros(128, 1000) for _ in range(len(self.orderlist))]
        for audio_file in audio_files:
            file_name = os.path.basename(audio_file)
            index = self.orderlist.index(file_name)


            y, sr = librosa.load(audio_file, sr=None)

            # STFT
            D = librosa.stft(y, n_fft=2048, hop_length=512)  # n_fft and hop_length can be adjusted based on your needs
            S = np.abs(D) ** 2  # Convert to power spectrum
            mel_spec = librosa.feature.melspectrogram(S=S, sr=sr, n_mels=128)

            # print(mel_spec)
            # plt.figure(figsize=(10, 4))
            # librosa.display.specshow(librosa.power_to_db(mel_spec, ref=np.max), sr=sr, hop_length=512, x_axis='time', y_axis='mel')
            # plt.colorbar(format='%+2.0f dB')
            # plt.title('Mel spectrogram')
            # plt.tight_layout()
            # plt.show()
            # print(len(y))
            # print(sr)

            # if self.transform:
            #     waveform = self.transform(waveform)
            waveform = PadTrimAudio(self.max_len)(torch.tensor(mel_spec))
            waveform_list[index] = waveform


        # Concatenate all waveforms along the time dimension
        waveform = torch.cat(waveform_list, dim=0)

        label = label_to_int[self.labels_df[idx][1]]

        return waveform, label

transform = AmplitudeNormalization()
data_dir = './data/data/Patients'
sound_dataset = SoundDataset(data_dir, label_list, transform=transform)

all_len =  len(label_list)
train_len = round(all_len * 0.9)

train_dataset, test_dataset = random_split(sound_dataset, [train_len, all_len-train_len])

traindataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
testdataloader = DataLoader(test_dataset, batch_size=4, shuffle=False)

dataloader = DataLoader(sound_dataset, batch_size=20, shuffle=True)

# %%
for batch in traindataloader:
    waveforms, labels = batch
    print(waveforms.shape)
    print(labels)
# Out:
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 0, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 1, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 0, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 0, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 0, 0, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 1, 0])
# torch.Size([4, 1280, 1000])
# tensor([0, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 1, 1, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 0, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 0, 0, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 0, 1, 0])
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 0, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 0, 0, 0])
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 1, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 0, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 1, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 0, 0, 0])
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 0, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 0, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 1, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 0, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 0, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([1, 0, 0, 1])
# torch.Size([1, 1280, 1000])
# tensor([0])

# %%
for batch in testdataloader:
    waveforms, labels = batch
    print(waveforms.shape)
    print(labels)
# Out:
# torch.Size([4, 1280, 1000])
# tensor([0, 1, 1, 0])
# torch.Size([4, 1280, 1000])
# tensor([1, 1, 1, 1])
# torch.Size([4, 1280, 1000])
# tensor([0, 0, 1, 1])
# torch.Size([3, 1280, 1000])
# tensor([1, 1, 0])

# %%
class AudioClassifier(nn.Module):
    def __init__(self):
        super(AudioClassifier, self).__init__()
        # Adjusted the number of input channels to 1280
        self.conv1 = nn.Conv1d(1280, 16, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool1d(2, 2)
        self.conv2 = nn.Conv1d(16, 32, kernel_size=3, stride=1, padding=1)

        # Calculate the size of the output from the last conv layer to pass to the first linear layer
        initial_length = 1000  # Initial length of the signal
        final_conv_length = self._get_conv1d_output_size(initial_length, 3, 1, 1, 2)  # After first conv and pool
        final_conv_length = self._get_conv1d_output_size(final_conv_length, 3, 1, 1, 2)  # After second conv and pool

        self.fc1 = nn.Linear(32 * final_conv_length, 128)  # Linear layer for feature reduction
        self.fc2 = nn.Linear(128, 2)  # Output layer for 3 classes

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)  # Flatten from the second dimension onward
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

    def _get_conv1d_output_size(self, L, kernel_size, stride, padding, pool):
        # Utility function to calculate the size of the output of a conv1d layer after pooling
        L = (L + 2 * padding - kernel_size) // stride + 1
        L = L // pool
        return L

class MLPClassifier(nn.Module):
    def __init__(self):
        super(MLPClassifier, self).__init__()
        # Flatten the input from 1280x1000 to 1280000
        self.fc1 = nn.Linear(1280 * 1000, 1024)  # First fully connected layer
        self.fc2 = nn.Linear(1024, 512)          # Second fully connected layer
        self.fc3 = nn.Linear(512, 3)             # Output layer for 3 classes

    def forward(self, x):
        # Flatten the input
        x = x.view(-1, 1280 * 1000)  # Ensure input tensor is reshaped to (batch_size, 1280*1000)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)  # No activation function here as it will be used with CrossEntropyLoss
        return x

# %%
import torch

def test_model(model, test_loader, device='cpu'):
    """
    Tests the given model on the provided test data loader.

    Parameters:
        model (torch.nn.Module): The model to test.
        test_loader (torch.utils.data.DataLoader): DataLoader for the test set.
        device (str): Device to run the model on ('cpu' or 'cuda').

    Returns:
        float: Accuracy of the model on the test set.
    """
    # Set the model to evaluation mode
    model.eval()
    model.to(device)

    correct = 0
    total = 0
    predictions = []
    true_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            print(labels)
            print(predicted)
            predictions.extend(predicted.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())


    accuracy = 100 * correct / total
    print(f'Accuracy of the model on the test set: {accuracy:.2f}%')


    return accuracy

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AudioClassifier().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

def train(model, device, train_loader, optimizer, criterion, num_epochs=10):
    model.train()
    for epoch in range(num_epochs):
        total_loss = 0
        correct = 0
        total = 0

        for data, targets in train_loader:
            data = data.to(device)
            targets = targets.to(device)

            optimizer.zero_grad()
            outputs = model(data)  # Add channel dimension
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            # Compute accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
            # print(total)
        avg_loss = total_loss / len(train_loader)
        accuracy = 100 * correct / total
        print(f'Epoch {epoch+1}, Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%')
        accuracy = test_model(model, testdataloader, device)

train(model, device, traindataloader, optimizer, criterion)
# Out:
# Epoch 1, Loss: 0.6904, Accuracy: 55.47%
# tensor([0, 1, 1, 0])
# tensor([0, 1, 1, 0])
# tensor([1, 1, 1, 1])
# tensor([0, 1, 0, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 0, 1, 0])
# tensor([1, 1, 0])
# tensor([0, 0, 0])
# Accuracy of the model on the test set: 66.67%
# Epoch 2, Loss: 0.6097, Accuracy: 59.12%
# tensor([0, 1, 1, 0])
# tensor([0, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([0, 1, 0, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 0, 1, 0])
# tensor([1, 1, 0])
# tensor([1, 0, 0])
# Accuracy of the model on the test set: 66.67%
# Epoch 3, Loss: 0.5171, Accuracy: 72.26%
# tensor([0, 1, 1, 0])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 1, 1, 1])
# tensor([1, 1, 0])
# tensor([1, 1, 1])
# Accuracy of the model on the test set: 73.33%
# Epoch 4, Loss: 0.4628, Accuracy: 75.18%
# tensor([0, 1, 1, 0])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 1, 1, 1])
# tensor([1, 1, 0])
# tensor([1, 1, 1])
# Accuracy of the model on the test set: 73.33%
# Epoch 5, Loss: 0.3467, Accuracy: 81.75%
# tensor([0, 1, 1, 0])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([0, 1, 1, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 0, 0, 0])
# tensor([1, 1, 0])
# tensor([1, 1, 0])
# Accuracy of the model on the test set: 66.67%
# Epoch 6, Loss: 0.2503, Accuracy: 90.51%
# tensor([0, 1, 1, 0])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 0, 0, 0])
# tensor([1, 1, 0])
# tensor([1, 1, 0])
# Accuracy of the model on the test set: 73.33%
# Epoch 7, Loss: 0.3289, Accuracy: 90.51%
# tensor([0, 1, 1, 0])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([0, 1, 1, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 0, 1, 1])
# tensor([1, 1, 0])
# tensor([1, 1, 0])
# Accuracy of the model on the test set: 80.00%
# Epoch 8, Loss: 0.3399, Accuracy: 83.94%
# tensor([0, 1, 1, 0])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([0, 0, 0, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 0, 0, 0])
# tensor([1, 1, 0])
# tensor([0, 0, 0])
# Accuracy of the model on the test set: 40.00%
# Epoch 9, Loss: 0.2669, Accuracy: 89.78%
# tensor([0, 1, 1, 0])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([0, 0, 0, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 1, 0, 1])
# tensor([1, 1, 0])
# tensor([1, 1, 1])
# Accuracy of the model on the test set: 46.67%
# Epoch 10, Loss: 0.1328, Accuracy: 94.89%
# tensor([0, 1, 1, 0])
# tensor([1, 1, 1, 1])
# tensor([1, 1, 1, 1])
# tensor([0, 0, 0, 1])
# tensor([0, 0, 1, 1])
# tensor([0, 1, 0, 0])
# tensor([1, 1, 0])
# tensor([1, 1, 1])
# Accuracy of the model on the test set: 40.00%
